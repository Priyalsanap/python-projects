# %%
import random

rock = '''
    _______
---'   ____)
      (_____)
      (_____)
      (____)
---.__(___)
'''
paper = '''
    _______
---'   ____)____
          ______)
          _______)
         _______)
---.__________)
'''
scissors = '''
    _______
---'   ____)____
          ______)
       __________)
      (____)
---.__(___)
'''

user_choice =int(input("What do you choose? Type 0 for rock, 1 for Paper or 2 for scissors.\n"))

computer_choice = random.randint(0,2)
print(f"computer choose {computer_choice}")

if user_choice == 0 and computer choice == 2 :
    print("You win!")
elif computer_choice > user_choice :
    print("You Loose!")
elif computer_choice > user_choice :
    print ("It's a draw")
else :
    print("You Loose!")
# Out:
#   Cell In[5], line 33
#     if user_choice == 0 and computer choice == 2 :
#                                      ^
# SyntaxError: invalid syntax

# %%
#randomisation and python lists
#random module- python module
#this whole number where 1 and 10 are inclusive
import random

random_integer= random.randint(50,60)
print(random_integer)
# every time you run this code you find a random integer between 1 to 10.
# Out:
# 51

# %%
#module- split a long code in small module according to the functionality then collabrate.
#random float point number- (0 to 1.0) exclusive

import random
random_float=random.random()
print(random_float)

#random float create a number between 0-1 but wht if we need a number between 0 to 5
#in this case we multiple by 5 (*5)
random_float*5
# Out:
# 0.07890248142412848
# 0.3945124071206424

# %%
import random

love_score=random.randint(1,100)
print(f" Your Love Score is {love_score}")
# Out:
#  Your Love Score is 42

# %%
import random

random_side= random.randint(0,1)
if random_side == 1 :
    print("Heads")
else:
    print("Tails")
# Out:
# Tails

# %%
#Python list- store data in one variable/ structure
#fruits=[item1, item2]

states_of_america= ["Delaware", "Illinois", "New jersey", "Maryland"]
print(states_of_america[0])
# here print with a number tells the order of the list.
#this list starts counting from 0.
#if you type-1,-2 list start backwards.
#your can also cahnge the name of an item from the list
#you can add to the list 
states_of_america.append("angeland")
print(states_of_america)

#you can extend remove and many othr function to use on this list
# Out:
# Delaware
# ['Delaware', 'Illinois', 'New jersey', 'Maryland', 'angeland']

# %%
import random
names=("Angela", "Ben", "Jenny", "Michael", "Chole")
#names= names_string.split(", ")
num_items=len(names)
random_choice= random.randint(0, 4)
#print(names[random_choice])
print(f"{names[random_choice]} is going to buy the meal today")
# Out:
# Ben is going to buy the meal today

# %%
#index error- you put a number which is beyond a list size
